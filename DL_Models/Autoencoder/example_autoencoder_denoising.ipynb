# %% [markdown]
# # Import

# %%
# De-noising input data and applying auto-decoder

import tensorflow as tf
import argparse

from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# C:\Users\Ali\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# # Parameters

# %%
#input size
input_size = 784
#re-constructed size
output_size = 784

# -------------------------------------------
# Following Hinton-Salakhutdinov Architecture

# 3 hidden layers for encoder
n_encoder_h_1 = 1000
n_encoder_h_2 = 500
n_encoder_h_3 = 250

# 3 hidden layers for decoder
n_decoder_h_1 = 250
n_decoder_h_2 = 500
n_decoder_h_3 = 1000


# Parameters
learning_rate = 0.01

training_epochs = 200
batch_size = 200
display_step = 1

# %% [markdown]
# # Batch Normalization

# %%
def layer_batch_normalization(x, n_out, phase_train):
    """
    Defines the network layers
    input:
        - x: input vector of the layer
        - n_out: integer, depth of input maps - number of sample in the batch 
        - phase_train: boolean tf.Varialbe, true indicates training phase
    output:
        - batch-normalized maps   
    """

    beta_init = tf.constant_initializer(value=0.0, dtype=tf.float32)
    beta = tf.get_variable("beta", [n_out], initializer=beta_init)
    
    gamma_init = tf.constant_initializer(value=1.0, dtype=tf.float32)
    gamma = tf.get_variable("gamma", [n_out], initializer=gamma_init)

    #tf.nn.moment: https://www.tensorflow.org/api_docs/python/tf/nn/moments
    #calculate mean and variance of x
    batch_mean, batch_var = tf.nn.moments(x, [0], name='moments')
    
    #tf.train.ExponentialMovingAverage:
    #https://www.tensorflow.org/api_docs/python/tf/train/ExponentialMovingAverage
    #Maintains moving averages of variables by employing an exponential decay.
    ema = tf.train.ExponentialMovingAverage(decay=0.9)
    ema_apply_op = ema.apply([batch_mean, batch_var])
    ema_mean, ema_var = ema.average(batch_mean), ema.average(batch_var)
    
    def mean_var_with_update():
        with tf.control_dependencies([ema_apply_op]):
            return tf.identity(batch_mean), tf.identity(batch_var)
        
    #tf.cond: https://www.tensorflow.org/api_docs/python/tf/cond
    #Return true_fn() if the predicate pred is true else false_fn()
    mean, var = tf.cond(phase_train, mean_var_with_update, lambda: (ema_mean, ema_var))

    reshaped_x = tf.reshape(x, [-1, 1, 1, n_out])
    normed = tf.nn.batch_norm_with_global_normalization(reshaped_x, mean, var, beta, gamma, 1e-3, True)
    #normed = tf.nn.batch_normalization(reshaped_x, mean, var, beta, gamma, 1e-3, True)
    
    return tf.reshape(normed, [-1, n_out])

# %% [markdown]
# # Definition of the Layer

# %%
def layer(x, weight_shape, bias_shape, phase_train):
    """
    Defines the network layers
    Using sigmoid to avoid sharp transitions in neurons
    input:
        - x: input vector of the layer
        - weight_shape: shape the the weight maxtrix
        - bias_shape: shape of the bias vector
        - phase_train: boolean tf.Variable, true indicates training phase
    output:
        - output vector of the layer after the matrix multiplication and non linear transformation
    """
    #initialize weights
    weight_init = tf.random_normal_initializer(stddev=(1.0/weight_shape[0])**0.5)
    W = tf.get_variable("W", weight_shape, initializer=weight_init)
    
    bias_init = tf.constant_initializer(value=0)
    b = tf.get_variable("b", bias_shape, initializer=bias_init)
    
    logits = tf.matmul(x, W) + b
    
    phase_train
    
    #apply the non-linear function after the batch normalization
    
    #return tf.nn.tanh(layer_batch_normalization(logits, weight_shape[1], phase_train))
    #return tf.nn.relu(layer_batch_normalization(logits, weight_shape[1], phase_train))
    return tf.nn.sigmoid(layer_batch_normalization(logits, weight_shape[1], phase_train))

# %% [markdown]
# # Definition of the Encoder Part

# %%
def encoder(x, n_code, phase_train):
    
    """
    Defines the network encoder part
    input:
        - x: input vector of the encoder
        - n_code: number of neurons in the code layer (output of the encoder - input of the decoder)
        - phase_train: boolean tf.Varialbe, true indicates training phase
    output:
        - output vector: reduced dimension
    """
    
    phase_train
    
    with tf.variable_scope("encoder"):
        
        with tf.variable_scope("h_1"):
            h_1 = layer(x, [input_size, n_encoder_h_1], [n_encoder_h_1], phase_train)

        with tf.variable_scope("h_2"):
            h_2 = layer(h_1, [n_encoder_h_1, n_encoder_h_2], [n_encoder_h_2], phase_train)

        with tf.variable_scope("h_3"):
            h_3 = layer(h_2, [n_encoder_h_2, n_encoder_h_3], [n_encoder_h_3], phase_train)

        with tf.variable_scope("code"):
            output = layer(h_3, [n_encoder_h_3, n_code], [n_code], phase_train)

    return output

# %% [markdown]
# # Definition of the Decoder Part

# %%
def decoder(x, n_code, phase_train):
    """
    Defines the network encoder part
    this mask is a noise added to the image 
    input:
        - x: input vector of the decoder - reduced dimension vector
        - n_code: number of neurons in the code layer (output of the encoder - input of the decoder) 
        - phase_train: boolean tf.Varialbe, true indicates training phase
    output:
        - output vector: reconstructed dimension of the initial vector
    """
    
    phase_train
    
    with tf.variable_scope("decoder"):
        
        with tf.variable_scope("h_1"):
            h_1 = layer(x, [n_code, n_decoder_h_1], [n_decoder_h_1], phase_train)

        with tf.variable_scope("h_2"):
            h_2 = layer(h_1, [n_decoder_h_1, n_decoder_h_2], [n_decoder_h_2], phase_train)

        with tf.variable_scope("h_3"):
            h_3 = layer(h_2, [n_decoder_h_2, n_decoder_h_3], [n_decoder_h_3], phase_train)

        with tf.variable_scope("output"):
            output = layer(h_3, [n_decoder_h_3, output_size], [output_size], phase_train)

    return output

# %% [markdown]
# # Definition of the corrupt functions

# %%
def corrupt_1(x):
    
    #Take an input tensor and add uniform masking
    #Parameters
    #----------
    #x : Tensor/Placeholder
    #    Input to corrupt.
    #Returns
    #-------
    #x_corrupted : Tensor
    #    50 pct of values corrupted.

    return tf.multiply(x, tf.cast(tf.random_uniform(shape=tf.shape(x), minval=0, maxval=2, dtype=tf.int32), tf.float32))


def corrupt_2(x):
    """
    Take an input tensor and add uniform masking.
    input:
        - x : input vector - to be corrupted
    output:
        - output vector : half of the values are corrupted
    """
    
    #https://www.tensorflow.org/api_docs/python/tf/random_uniform
    #Outputs random values from a uniform distribution.
    #The lower bound minval is included in the range, while the upper bound maxval is excluded.
    #here 0 or 1
    c = tf.random_uniform(shape=tf.shape(x),  minval=0, maxval=2, dtype=tf.int32)
    
    #https://www.tensorflow.org/api_docs/python/tf/cast
    #change the type to float
        
    return x * tf.cast(c, tf.float32)

# %% [markdown]
# # Definition of the Loss

# %%
def loss(output, x):
    """
    Compute the loss of the auto-encoder
    intput:
        - output: the output of the decoder
        - x: true value of the sample batch - this is the input of the encoder
        
        the two have the same shape (batch_size * num_of_classes)
    output:
        - loss: loss of the corresponding batch (scalar tensor)
    
    """
    with tf.variable_scope("training"):
        
        l2_measure = tf.sqrt(tf.reduce_sum(tf.square(tf.subtract(output, x)), 1))
        train_loss = tf.reduce_mean(l2_measure)
        train_summary_op = tf.summary.scalar("train_cost", train_loss)
        return train_loss, train_summary_op

# %% [markdown]
# # Training Function

# %%
def training(cost, global_step):
    """
    defines the necessary elements to train the network
    
    intput:
        - cost: the cost is the loss of the corresponding batch
        - global_step: number of batch seen so far, it is incremented by one 
        each time the .minimize() function is called
    """
    # Using Adam for optimization
    optimizer = tf.train.AdamOptimizer(learning_rate=0.001, beta1=0.9, beta2=0.999, epsilon=1e-08, use_locking=False, name='Adam')
    train_op = optimizer.minimize(cost, global_step=global_step)
    return train_op

# %% [markdown]
# # Evaluation Function

# %%
def evaluate(output, x, x_tilde):
    """
    evaluates the accuracy on the validation set 
    input:
        -output: prediction vector of the network for the validation set
        -x: true value for the validation set
        -x_tilde: corrupted image with a level c
    output:
        - val_loss: loss of the autoencoder
        - in_image_op: input image 
        - out_image_op:reconstructed image 
        - val_summary_op: summary of the loss
    """
    
    with tf.variable_scope("validation"):
        
        #input of the autoencoder is the corrupted image
        in_image_op = image_summary("input_image", x_tilde)
        
        #output image
        out_image_op = image_summary("output_image", output)
        
        #the validation loss is computed using the original image 
        l2_norm = tf.sqrt(tf.reduce_sum(tf.square(tf.subtract(output, x, name="val_diff")), 1))
        
        val_loss = tf.reduce_mean(l2_norm)
        
        val_summary_op = tf.summary.scalar("val_cost", val_loss)
        
        return val_loss, in_image_op, out_image_op, val_summary_op

# %% [markdown]
# # Image Summary

# %%
def image_summary(label, tensor):
    #tf.summary.image: https://www.tensorflow.org/api_docs/python/tf/summary/image
    #Outputs a Summary protocol buffer with images.
    
    tensor_reshaped = tf.reshape(tensor, [-1, 28, 28, 1])
    return tf.summary.image(label, tensor_reshaped)

# %% [markdown]
# # Main Function

# %%
if __name__ == '__main__':

    # passing arguments through command line

    # if a python file, please use the 4 lines bellow and comment the "n_code = '1'"
    #parser = argparse.ArgumentParser(description='Autoencoder')
    #parser.add_argument('n_code', nargs=1, type=str)
    #args = parser.parse_args()
    #n_code = args.n_code[0]

    # if a jupyter file, please comment the 4 above and use the one bellow
    n_code = '2'

    model_path = 'C:/Users/Ali/logs/restore_2/model.ckpt'
    #model_path = 'C:/Users/Ali/logs/restore/'

    with tf.Graph().as_default():

        with tf.variable_scope("autoencoder_model"):

            # the input variables are first define as placeholder
            # a placeholder is a variable/data which will be assigned later
            # image vector & label, phase_train is a boolean
            # MNIST data image of shape 28*28=784
            x = tf.placeholder("float", [None, 784])

            phase_train = tf.placeholder(tf.bool)

            # the parameter c is also defined as a placeholder
            c = tf.placeholder(tf.float32)

            #x_tilde = x*(1.0 - c) + corrupt_x(x)*c
            x_tilde = corrupt_1(x)

            # define the encoder
            code = encoder(x_tilde, int(n_code), phase_train)

            # define the decoder
            output = decoder(code, int(n_code), phase_train)

            # compute the loss
            cost, train_summary_op = loss(output, x)

            # initialize the value of the global_step variable
            # recall: it is incremented by one each time the .minimise() is called
            global_step = tf.Variable(0, name='global_step', trainable=False)

            train_op = training(cost, global_step)

            # evaluate the accuracy of the network (done on a validation set)
            eval_op, in_image_op, out_image_op, val_summary_op = evaluate(output, x, x_tilde)

            summary_op = tf.summary.merge_all()

            # save and restore variables to and from checkpoints.
            saver = tf.train.Saver()

            # defines a session
            # A session allows to execute graphs or part of graphs
            # It allocates resources (on one or more machines) for that
            # and holds the actual values of intermediate results and variables
            sess = tf.Session()

            # summary writer
            # https://www.tensorflow.org/api_docs/python/tf/summary/FileWriter
            train_writer = tf.summary.FileWriter(model_path, graph=sess.graph)
            val_writer = tf.summary.FileWriter(model_path, graph=sess.graph)

            # initialization of the variables
            init_op = tf.global_variables_initializer()

            sess.run(init_op)

            # Training cycle
            for epoch in range(training_epochs):

                avg_cost = 0.
                total_batch = int(mnist.train.num_examples/batch_size)

                # Loop over all batches
                for i in range(total_batch):

                    minibatch_x, minibatch_y = mnist.train.next_batch(batch_size)

                    # Fit training using batch data
                    # the training is done using the training dataset
                    _, new_cost, train_summary = sess.run([train_op, cost, train_summary_op], feed_dict={
                                                          x: minibatch_x, phase_train: True, c: 1.0})

                    train_writer.add_summary(train_summary, sess.run(global_step))

                    # Compute average loss
                    avg_cost += new_cost/total_batch

                # Display logs per epoch step
                if epoch % display_step == 0:

                    print("Epoch:", '%04d' % (epoch+1),
                          "cost =", "{:.9f}".format(avg_cost))

                    train_writer.add_summary(
                        train_summary, sess.run(global_step))

                    validation_loss, in_image, out_image, val_summary = sess.run([eval_op, in_image_op, out_image_op, val_summary_op], feed_dict={
                                                                                 x: mnist.validation.images, phase_train: False, c: 1.0})

                    val_writer.add_summary(in_image, sess.run(global_step))
                    val_writer.add_summary(out_image, sess.run(global_step))
                    val_writer.add_summary(val_summary, sess.run(global_step))

                    print("Validation Loss:", validation_loss)

                    save_path = saver.save(sess, model_path)
                    print("Model saved in file: %s" % save_path)

            print("Optimization Done")

            test_loss = sess.run(eval_op, feed_dict={
                                 x: mnist.test.images, phase_train: False, c: 0.0})

            print("Test Loss:", test_loss)
# Out:
# Epoch: 0001 cost = 12.328632899
# Validation Loss: 11.1034
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0002 cost = 10.741893730
# Validation Loss: 9.96536
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0003 cost = 9.664100304
# Validation Loss: 9.113872
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0004 cost = 8.907422024
# Validation Loss: 8.373998
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0005 cost = 8.504339825
# Validation Loss: 8.133545
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0006 cost = 8.038612347
# Validation Loss: 7.5137353
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0007 cost = 7.742828803
# Validation Loss: 7.7705045
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0008 cost = 7.517089003
# Validation Loss: 10.476646
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0009 cost = 7.317576204
# Validation Loss: 7.921607
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0010 cost = 7.222624902
# Validation Loss: 7.4451313
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0011 cost = 7.049131012
# Validation Loss: 6.9884257
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0012 cost = 6.966231663
# Validation Loss: 6.742994
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0013 cost = 6.901952520
# Validation Loss: 7.006509
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0014 cost = 6.763386151
# Validation Loss: 6.891732
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0015 cost = 6.682951324
# Validation Loss: 6.7710013
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0016 cost = 6.562908212
# Validation Loss: 6.3958573
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0017 cost = 6.446309514
# Validation Loss: 6.3108015
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0018 cost = 6.238685781
# Validation Loss: 6.132422
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0019 cost = 6.126877693
# Validation Loss: 6.0256944
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0020 cost = 6.067850319
# Validation Loss: 6.014132
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0021 cost = 6.017056439
# Validation Loss: 5.9509764
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0022 cost = 5.968891992
# Validation Loss: 5.9393697
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0023 cost = 5.939288795
# Validation Loss: 5.843532
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0024 cost = 5.905206065
# Validation Loss: 5.950781
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0025 cost = 5.880955315
# Validation Loss: 5.789524
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0026 cost = 5.845708063
# Validation Loss: 5.799942
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0027 cost = 5.831049326
# Validation Loss: 5.7405133
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0028 cost = 5.803149678
# Validation Loss: 5.7322187
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0029 cost = 5.777287046
# Validation Loss: 5.705304
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0030 cost = 5.769620422
# Validation Loss: 5.6921287
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0031 cost = 5.739152097
# Validation Loss: 5.654257
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0032 cost = 5.729578261
# Validation Loss: 5.649374
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0033 cost = 5.715967957
# Validation Loss: 5.688867
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0034 cost = 5.706943730
# Validation Loss: 5.6203837
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0035 cost = 5.667556288
# Validation Loss: 5.736847
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0036 cost = 5.665377749
# Validation Loss: 5.582981
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0037 cost = 5.648527048
# Validation Loss: 5.5698314
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0038 cost = 5.639637612
# Validation Loss: 5.571934
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0039 cost = 5.620723652
# Validation Loss: 5.577457
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0040 cost = 5.607485738
# Validation Loss: 5.494768
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0041 cost = 5.580515270
# Validation Loss: 5.5066338
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0042 cost = 5.600397771
# Validation Loss: 5.5261736
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0043 cost = 5.581940505
# Validation Loss: 5.49865
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0044 cost = 5.558245706
# Validation Loss: 5.489062
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0045 cost = 5.553268304
# Validation Loss: 5.4761367
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0046 cost = 5.539317131
# Validation Loss: 5.480172
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0047 cost = 5.530671571
# Validation Loss: 5.464348
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0048 cost = 5.514184700
# Validation Loss: 5.461586
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0049 cost = 5.520767914
# Validation Loss: 5.3958583
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0050 cost = 5.504490759
# Validation Loss: 5.422105
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0051 cost = 5.499893575
# Validation Loss: 5.437601
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0052 cost = 5.486697443
# Validation Loss: 5.419653
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0053 cost = 5.482453478
# Validation Loss: 5.4001265
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0054 cost = 5.475201114
# Validation Loss: 5.358031
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0055 cost = 5.481396247
# Validation Loss: 5.3602905
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0056 cost = 5.451235364
# Validation Loss: 5.377473
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0057 cost = 5.447820610
# Validation Loss: 5.341632
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0058 cost = 5.444891727
# Validation Loss: 5.3486843
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0059 cost = 5.440111760
# Validation Loss: 5.3799767
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0060 cost = 5.443883709
# Validation Loss: 5.3321795
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0061 cost = 5.430765279
# Validation Loss: 5.3235703
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0062 cost = 5.424136002
# Validation Loss: 5.3220296
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0063 cost = 5.412222063
# Validation Loss: 5.320735
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0064 cost = 5.421560286
# Validation Loss: 5.409914
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0065 cost = 5.410224089
# Validation Loss: 5.305594
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0066 cost = 5.398943074
# Validation Loss: 5.316926
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0067 cost = 5.410236131
# Validation Loss: 5.2770452
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0068 cost = 5.387557123
# Validation Loss: 5.2899594
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0069 cost = 5.398471707
# Validation Loss: 5.2728944
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0070 cost = 5.391634086
# Validation Loss: 5.285689
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0071 cost = 5.386549206
# Validation Loss: 5.355979
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0072 cost = 5.377431601
# Validation Loss: 5.284487
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0073 cost = 5.373800682
# Validation Loss: 5.2851543
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0074 cost = 5.368290022
# Validation Loss: 5.2500587
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0075 cost = 5.366392793
# Validation Loss: 5.2580004
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0076 cost = 5.365396600
# Validation Loss: 5.242038
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0077 cost = 5.351641964
# Validation Loss: 5.2458997
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0078 cost = 5.349459674
# Validation Loss: 5.2859545
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0079 cost = 5.352064403
# Validation Loss: 5.258039
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0080 cost = 5.354916521
# Validation Loss: 5.213434
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0081 cost = 5.335710432
# Validation Loss: 5.242429
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0082 cost = 5.333474340
# Validation Loss: 5.2449446
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0083 cost = 5.342562377
# Validation Loss: 5.251499
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0084 cost = 5.334698838
# Validation Loss: 5.3166084
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0085 cost = 5.324253739
# Validation Loss: 5.291963
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0086 cost = 5.332590190
# Validation Loss: 5.214484
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0087 cost = 5.319015607
# Validation Loss: 5.21297
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0088 cost = 5.314973160
# Validation Loss: 5.26394
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0089 cost = 5.325893976
# Validation Loss: 5.2372584
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0090 cost = 5.312879233
# Validation Loss: 5.1847296
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0091 cost = 5.307871519
# Validation Loss: 5.18957
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0092 cost = 5.316200331
# Validation Loss: 5.174617
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0093 cost = 5.293660174
# Validation Loss: 5.198285
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0094 cost = 5.293745844
# Validation Loss: 5.1783586
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0095 cost = 5.293343672
# Validation Loss: 5.2424154
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0096 cost = 5.288094569
# Validation Loss: 5.178365
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0097 cost = 5.284781725
# Validation Loss: 5.2205057
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0098 cost = 5.293435929
# Validation Loss: 5.2540736
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0099 cost = 5.291756926
# Validation Loss: 5.1602936
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0100 cost = 5.282669660
# Validation Loss: 5.208576
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0101 cost = 5.284014466
# Validation Loss: 5.1558022
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0102 cost = 5.281322989
# Validation Loss: 5.225557
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0103 cost = 5.260803160
# Validation Loss: 5.1669273
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0104 cost = 5.273069676
# Validation Loss: 5.1584764
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0105 cost = 5.277546359
# Validation Loss: 5.221617
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0106 cost = 5.277812167
# Validation Loss: 5.1480722
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0107 cost = 5.267227880
# Validation Loss: 5.190943
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0108 cost = 5.255786627
# Validation Loss: 5.177996
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0109 cost = 5.255491158
# Validation Loss: 5.18512
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0110 cost = 5.257999708
# Validation Loss: 5.1328874
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0111 cost = 5.265529340
# Validation Loss: 5.158426
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0112 cost = 5.246424241
# Validation Loss: 5.159503
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0113 cost = 5.253047352
# Validation Loss: 5.1628313
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0114 cost = 5.245910561
# Validation Loss: 5.1434
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0115 cost = 5.258264980
# Validation Loss: 5.135441
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0116 cost = 5.253095774
# Validation Loss: 5.13882
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0117 cost = 5.244823900
# Validation Loss: 5.149427
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0118 cost = 5.242714972
# Validation Loss: 5.1381063
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0119 cost = 5.248705349
# Validation Loss: 5.1580267
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0120 cost = 5.228206085
# Validation Loss: 5.133669
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0121 cost = 5.240341696
# Validation Loss: 5.102015
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0122 cost = 5.229379179
# Validation Loss: 5.120369
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0123 cost = 5.228662252
# Validation Loss: 5.1210227
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0124 cost = 5.234606680
# Validation Loss: 5.1186523
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0125 cost = 5.223531848
# Validation Loss: 5.1332984
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0126 cost = 5.236910775
# Validation Loss: 5.1099353
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0127 cost = 5.224538763
# Validation Loss: 5.1664276
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0128 cost = 5.225652780
# Validation Loss: 5.113176
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0129 cost = 5.224505161
# Validation Loss: 5.1044803
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0130 cost = 5.212828137
# Validation Loss: 5.1013546
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0131 cost = 5.227853378
# Validation Loss: 5.1076427
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0132 cost = 5.217172288
# Validation Loss: 5.1099334
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0133 cost = 5.218080524
# Validation Loss: 5.076293
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0134 cost = 5.206014649
# Validation Loss: 5.0814424
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0135 cost = 5.216479242
# Validation Loss: 5.111545
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0136 cost = 5.200542634
# Validation Loss: 5.08162
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0137 cost = 5.207774355
# Validation Loss: 5.0923066
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0138 cost = 5.213107425
# Validation Loss: 5.0984397
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0139 cost = 5.207251238
# Validation Loss: 5.085804
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0140 cost = 5.201661934
# Validation Loss: 5.0882525
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0141 cost = 5.204268622
# Validation Loss: 5.128411
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0142 cost = 5.199926198
# Validation Loss: 5.099066
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0143 cost = 5.194483899
# Validation Loss: 5.11306
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0144 cost = 5.199389603
# Validation Loss: 5.07614
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0145 cost = 5.198007344
# Validation Loss: 5.0766234
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0146 cost = 5.191464565
# Validation Loss: 5.076571
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0147 cost = 5.181988735
# Validation Loss: 5.102293
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0148 cost = 5.190762404
# Validation Loss: 5.0923157
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0149 cost = 5.194684911
# Validation Loss: 5.079742
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0150 cost = 5.188274560
# Validation Loss: 5.055598
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0151 cost = 5.187393830
# Validation Loss: 5.0857716
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0152 cost = 5.185209742
# Validation Loss: 5.1200476
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0153 cost = 5.190195118
# Validation Loss: 5.089521
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0154 cost = 5.178526195
# Validation Loss: 5.077767
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0155 cost = 5.186298915
# Validation Loss: 5.0779905
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0156 cost = 5.177252496
# Validation Loss: 5.0789657
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0157 cost = 5.172615702
# Validation Loss: 5.106373
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0158 cost = 5.176331350
# Validation Loss: 5.071015
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0159 cost = 5.170482287
# Validation Loss: 5.0455985
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0160 cost = 5.177808706
# Validation Loss: 5.0862727
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0161 cost = 5.167168772
# Validation Loss: 5.0439696
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0162 cost = 5.164984493
# Validation Loss: 5.0483813
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0163 cost = 5.167688177
# Validation Loss: 5.062729
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0164 cost = 5.165077939
# Validation Loss: 5.083428
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0165 cost = 5.170146004
# Validation Loss: 5.087341
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0166 cost = 5.162879486
# Validation Loss: 5.0788417
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0167 cost = 5.161049014
# Validation Loss: 5.047848
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0168 cost = 5.157511409
# Validation Loss: 5.0424232
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0169 cost = 5.170544682
# Validation Loss: 5.031689
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0170 cost = 5.159678400
# Validation Loss: 5.0789237
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0171 cost = 5.156563136
# Validation Loss: 5.090017
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0172 cost = 5.161463073
# Validation Loss: 5.053539
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0173 cost = 5.148375823
# Validation Loss: 5.041158
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0174 cost = 5.158034385
# Validation Loss: 5.046871
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0175 cost = 5.157480138
# Validation Loss: 5.0360866
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0176 cost = 5.147485039
# Validation Loss: 5.046808
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0177 cost = 5.148512206
# Validation Loss: 5.046812
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0178 cost = 5.160624664
# Validation Loss: 5.0855603
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0179 cost = 5.134731750
# Validation Loss: 5.0627756
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0180 cost = 5.142265970
# Validation Loss: 5.0677457
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0181 cost = 5.144290541
# Validation Loss: 5.028671
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0182 cost = 5.141069029
# Validation Loss: 5.0393424
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0183 cost = 5.145176874
# Validation Loss: 5.028578
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0184 cost = 5.133844884
# Validation Loss: 5.034406
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0185 cost = 5.139760881
# Validation Loss: 5.045249
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0186 cost = 5.131393136
# Validation Loss: 5.0756316
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0187 cost = 5.137892695
# Validation Loss: 5.033307
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0188 cost = 5.134897938
# Validation Loss: 5.068976
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0189 cost = 5.123107341
# Validation Loss: 5.0390487
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0190 cost = 5.138658463
# Validation Loss: 5.0436106
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0191 cost = 5.125140924
# Validation Loss: 5.0239635
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0192 cost = 5.132902728
# Validation Loss: 5.019586
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0193 cost = 5.124129651
# Validation Loss: 5.077243
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0194 cost = 5.131109056
# Validation Loss: 5.0307875
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0195 cost = 5.120131574
# Validation Loss: 5.050496
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0196 cost = 5.126752434
# Validation Loss: 5.0622883
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0197 cost = 5.128618459
# Validation Loss: 5.0749955
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0198 cost = 5.120434135
# Validation Loss: 5.092863
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0199 cost = 5.132269934
# Validation Loss: 5.0124607
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Epoch: 0200 cost = 5.119022444
# Validation Loss: 5.032852
# Model saved in file: C:/Users/Ali/logs/restore_2/model.ckpt
# Optimization Done
# Test Loss: 5.110005
