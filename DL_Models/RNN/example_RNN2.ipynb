# %% [markdown]
# # Import

# %%
'''
A Recurrent Neural Network (LSTM) implementation example using TensorFlow

Next word prediction after n_input words learned from text file

A story is automatically generated if the predicted word is fed back as input

Based on Rowel Atienza's code
'''

from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn

import numpy as np
import random
import collections

import time
# Out:
# C:\Users\Ali\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# # Record Elapsed time

# %%
def time_elapsed(t):

    if t<60:
        return str(t) + " second(s)"
    elif t<(60*60):
        return str(t/60) + " minute(s)"
    else:
        return str(t/(60*60)) + " hour(s)"

# %% [markdown]
# # Build Dataset

# %%
# read word data from files
def read_data(fname):
    
    with open(fname) as f:
        content = f.readlines()
    # strip useless indent    
    content = [x.strip() for x in content]
    content = [word for i in range(len(content)) for word in content[i].split()]
    content = np.array(content)
    return content


#module for building dictionary and reverse dictionary.
def build_dataset(words):
    #Return a list of the n most common elements and their counts from the most common to the least. 
    #If n is omitted or None, most_common() returns all elements in the counter.
    count = collections.Counter(words).most_common()
    dictionary = dict()
    for word, _ in count:
        #key of the dictionary is the word and take the index of frequencies as the corresponding value
        dictionary[word] = len(dictionary)
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return dictionary, reverse_dictionary

# %% [markdown]
# # Function for Building RNN Layers

# %%
def module_RNN(x, weights, biases):
    #weights and biases are dictionaries with a key as 'out' and content as a matrix or an array
    # reshape to [1, n_input]
    x = tf.reshape(x, [-1, n_input])

    # Generate a n_input-element sequence of inputs
    # (e.g. [A] [slave] [named] -> [9] [10] [37])
    x = tf.split(x,n_input,1)
    
    # basic RNN cell
    #rnn_cell = rnn.BasicRNNCell(n_hidden)

    # 1-layer LSTM with n_hidden units
    rnn_cell = rnn.BasicLSTMCell(n_hidden)
    
    # 2-layer LSTM, each layer has n_hidden units. And you can wrap more layers together by doing list comprehension.
    #rnn_cell = rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden)])

    # 3-layer LSTM, each layer has n_hidden units. 
    # And you can wrap more layers together by doing list comprehension.
    #rnn_cell = rnn.MultiRNNCell([rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden),rnn.BasicLSTMCell(n_hidden)])

    # generate prediction
    # creates a recurrent neural network specified by RNNCell cell
    outputs, states = rnn.static_rnn(rnn_cell, x, dtype=tf.float32)

    # there are n_input outputs but
    # we only want the last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

# %% [markdown]
# # Parameters and Load Data

# %%
# Parameters
learning_rate = 0.001

training_iters = 50000

display_step = 100
# number of words to be put into the network
n_input = 3

# number of units in RNN cell
n_hidden = 5


# Text file containing words for training
training_file = 'simpleStory.txt'
#training_file = 'androcles.txt'

training_data = read_data(training_file)
print("Loaded training data...")

dictionary, reverse_dictionary = build_dataset(training_data)
vocab_size = len(dictionary)
# Out:
# Loaded training data...

# %% [markdown]
# # Main Function

# %%
# TensorFlow Graph input
x = tf.placeholder("float", [None, n_input, 1])
y = tf.placeholder("float", [None, vocab_size])


# Logs_path
logs_path = 'C:/Users/Ali/logs/RNNs'
writer  = tf.summary.FileWriter(logs_path)

# RNN output node weights and biases
weights = {'out': tf.Variable(tf.random_normal([n_hidden, vocab_size]))}
biases  = {'out': tf.Variable(tf.random_normal([vocab_size]))}

# get the prediction in the probability form from the output of wraped RNN layers
pred = module_RNN(x, weights, biases)

# Loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

# Model evaluation
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

start_time = time.time()

# Launch the graph
with tf.Session() as session:
    session.run(init)
    step = 0
    offset = random.randint(0, n_input+1)
    end_offset = n_input + 1
    acc_total = 0
    loss_total = 0

    writer.add_graph(session.graph)

    while step < training_iters:

        # Generate a mini-batch
        # Add some randomness on selection process

        if offset > (len(training_data)-end_offset):
            offset = random.randint(0, n_input+1)
            
        #select size of n_input data from the training set and reshape them.
        symbols_in_keys = [ [dictionary[ str(training_data[i])]] for i in range(offset, offset+n_input) ]
        symbols_in_keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
        
        #set up the one-hot-encoding of the labels and reshape them
        symbols_out_onehot = np.zeros([vocab_size], dtype=float)
        symbols_out_onehot[dictionary[str(training_data[offset+n_input])]] = 1.0
        symbols_out_onehot = np.reshape(symbols_out_onehot,[1,-1])
        
        # run optimizer,accuracy,cost and pred tensors and get the results
        _, acc, loss, onehot_pred = session.run([optimizer, accuracy, cost, pred], feed_dict={x: symbols_in_keys, y: symbols_out_onehot})

        loss_total += loss
        acc_total += acc
        
        #display the trend of loss and accuracy
        if (step+1) % display_step == 0:
            print("Iter = " + str(step+1) + ", average loss= " + \
                  "{:0.6f}".format(loss_total/display_step) + ", average accuracy= " + \
                  "{:0.2f}%".format(100*acc_total/display_step))
            #reset
            acc_total = 0
            loss_total = 0
            
            #have a brief view of the relationship of input, real value and prediction result
            symbols_in = [training_data[i] for i in range(offset, offset + n_input)]
            symbols_out = training_data[offset + n_input]
            symbols_out_pred = reverse_dictionary[int(tf.argmax(onehot_pred, 1).eval())]
            
            print("%s - [%s] vs [%s]" % (symbols_in, symbols_out, symbols_out_pred))
        step += 1
        offset += (n_input+1)
    print("Optimization Finished!")
    
    t_elapsed = time.time() - start_time
    print("Elapsed time: ", time_elapsed(t_elapsed))
    
    #Take a simple experiment using customized input
    while True:
        
        prompt = "insert %s words: " % n_input
        sentence = input(prompt)
        sentence = sentence.strip()
        words = sentence.split(' ')
        
        if len(words) != n_input:
            continue
        try:
            symbols_in_keys = [dictionary[str(words[i])] for i in range(len(words))]
            
            # how many many words
            for i in range(10):
                keys = np.reshape(np.array(symbols_in_keys), [-1, n_input, 1])
                onehot_pred = session.run(pred, feed_dict={x: keys})
                onehot_pred_index = int(tf.argmax(onehot_pred, 1).eval())
                sentence = "%s %s" % (sentence, reverse_dictionary[onehot_pred_index])
                symbols_in_keys = symbols_in_keys[1:]
                symbols_in_keys.append(onehot_pred_index)
                
            print(sentence)
        except:
            print("cannot be found in dictionary")
# Out:
# Iter = 100, average loss= 2.249367, average accuracy= 30.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 200, average loss= 2.266527, average accuracy= 12.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [.]
# Iter = 300, average loss= 2.249628, average accuracy= 0.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [with]
# Iter = 400, average loss= 2.157445, average accuracy= 2.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [.]
# Iter = 500, average loss= 2.127943, average accuracy= 5.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [with]
# Iter = 600, average loss= 1.985189, average accuracy= 11.00%
# ['Steve', '.', 'Steve'] - [had] vs [.]
# Iter = 700, average loss= 2.008005, average accuracy= 17.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [with]
# Iter = 800, average loss= 1.932054, average accuracy= 13.00%
# ['dinner', 'with', 'Steve'] - [.] vs [with]
# Iter = 900, average loss= 1.823905, average accuracy= 21.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 1000, average loss= 2.014652, average accuracy= 18.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [with]
# Iter = 1100, average loss= 1.828377, average accuracy= 25.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [.]
# Iter = 1200, average loss= 1.868152, average accuracy= 25.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 1300, average loss= 1.829268, average accuracy= 33.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [with]
# Iter = 1400, average loss= 1.690160, average accuracy= 48.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [with]
# Iter = 1500, average loss= 1.886911, average accuracy= 36.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [with]
# Iter = 1600, average loss= 1.795718, average accuracy= 39.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 1700, average loss= 1.714722, average accuracy= 45.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [with]
# Iter = 1800, average loss= 1.486496, average accuracy= 55.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [with]
# Iter = 1900, average loss= 1.645527, average accuracy= 49.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2000, average loss= 1.604512, average accuracy= 48.00%
# ['Steve', '.', 'Steve'] - [had] vs [.]
# Iter = 2100, average loss= 1.635514, average accuracy= 57.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 2200, average loss= 1.607186, average accuracy= 53.00%
# ['Steve', '.', 'Steve'] - [had] vs [.]
# Iter = 2300, average loss= 1.686849, average accuracy= 53.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 2400, average loss= 1.506567, average accuracy= 62.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 2500, average loss= 1.286937, average accuracy= 67.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 2600, average loss= 1.522918, average accuracy= 58.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 2700, average loss= 1.425097, average accuracy= 60.00%
# ['Steve', '.', 'Steve'] - [had] vs [.]
# Iter = 2800, average loss= 1.094441, average accuracy= 69.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 2900, average loss= 1.270691, average accuracy= 61.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 3000, average loss= 1.147759, average accuracy= 73.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 3100, average loss= 1.113104, average accuracy= 65.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3200, average loss= 1.497352, average accuracy= 48.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 3300, average loss= 1.080567, average accuracy= 66.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 3400, average loss= 1.186064, average accuracy= 59.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 3500, average loss= 1.368021, average accuracy= 53.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [with]
# Iter = 3600, average loss= 1.093077, average accuracy= 61.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [Sarah]
# Iter = 3700, average loss= 1.014308, average accuracy= 68.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 3800, average loss= 0.745515, average accuracy= 80.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [with]
# Iter = 3900, average loss= 1.221584, average accuracy= 59.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4000, average loss= 0.795118, average accuracy= 78.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4100, average loss= 1.033875, average accuracy= 68.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 4200, average loss= 1.368249, average accuracy= 55.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4300, average loss= 1.083971, average accuracy= 67.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [Sarah]
# Iter = 4400, average loss= 0.958127, average accuracy= 72.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [Sarah]
# Iter = 4500, average loss= 1.091469, average accuracy= 65.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 4600, average loss= 0.951718, average accuracy= 70.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 4700, average loss= 1.054698, average accuracy= 64.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 4800, average loss= 0.953075, average accuracy= 68.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 4900, average loss= 0.967978, average accuracy= 65.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 5000, average loss= 1.002159, average accuracy= 64.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 5100, average loss= 0.889669, average accuracy= 68.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 5200, average loss= 0.673015, average accuracy= 78.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 5300, average loss= 0.693583, average accuracy= 79.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 5400, average loss= 0.897719, average accuracy= 70.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [with]
# Iter = 5500, average loss= 0.755599, average accuracy= 75.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 5600, average loss= 0.755286, average accuracy= 74.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 5700, average loss= 0.532351, average accuracy= 82.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 5800, average loss= 0.581598, average accuracy= 80.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 5900, average loss= 0.684112, average accuracy= 73.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 6000, average loss= 0.780932, average accuracy= 75.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 6100, average loss= 0.517555, average accuracy= 83.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 6200, average loss= 0.490744, average accuracy= 85.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 6300, average loss= 0.713186, average accuracy= 76.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 6400, average loss= 0.461438, average accuracy= 87.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 6500, average loss= 0.501306, average accuracy= 84.00%
# ['had', 'breakfast', 'with'] - [David] vs [with]
# Iter = 6600, average loss= 0.657218, average accuracy= 78.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 6700, average loss= 0.565660, average accuracy= 83.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 6800, average loss= 0.508784, average accuracy= 83.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 6900, average loss= 0.677999, average accuracy= 77.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Sarah]
# Iter = 7000, average loss= 0.694010, average accuracy= 76.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 7100, average loss= 0.396994, average accuracy= 88.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 7200, average loss= 0.363572, average accuracy= 89.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 7300, average loss= 0.538088, average accuracy= 81.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 7400, average loss= 0.524355, average accuracy= 82.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 7500, average loss= 0.497679, average accuracy= 82.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 7600, average loss= 0.574602, average accuracy= 78.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 7700, average loss= 0.522277, average accuracy= 80.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 7800, average loss= 0.681885, average accuracy= 72.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 7900, average loss= 0.547247, average accuracy= 80.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 8000, average loss= 0.326098, average accuracy= 88.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 8100, average loss= 0.454074, average accuracy= 83.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Sarah]
# Iter = 8200, average loss= 0.575028, average accuracy= 76.00%
# ['had', 'breakfast', 'with'] - [David] vs [Steve]
# Iter = 8300, average loss= 0.418218, average accuracy= 84.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 8400, average loss= 0.380489, average accuracy= 85.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 8500, average loss= 0.323487, average accuracy= 91.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 8600, average loss= 0.413336, average accuracy= 86.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 8700, average loss= 0.311604, average accuracy= 88.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 8800, average loss= 0.467189, average accuracy= 80.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 8900, average loss= 0.461544, average accuracy= 83.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 9000, average loss= 0.362788, average accuracy= 91.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 9100, average loss= 0.372118, average accuracy= 92.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 9200, average loss= 0.370171, average accuracy= 89.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 9300, average loss= 0.367179, average accuracy= 92.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 9400, average loss= 0.294893, average accuracy= 96.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 9500, average loss= 0.506091, average accuracy= 82.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 9600, average loss= 0.443862, average accuracy= 85.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 9700, average loss= 0.422896, average accuracy= 90.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 9800, average loss= 0.319593, average accuracy= 92.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 9900, average loss= 0.426132, average accuracy= 81.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 10000, average loss= 0.249956, average accuracy= 90.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 10100, average loss= 0.439234, average accuracy= 91.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 10200, average loss= 0.360951, average accuracy= 92.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 10300, average loss= 0.305109, average accuracy= 92.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 10400, average loss= 0.267047, average accuracy= 92.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 10500, average loss= 0.268646, average accuracy= 90.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 10600, average loss= 0.192089, average accuracy= 95.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 10700, average loss= 0.357959, average accuracy= 93.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 10800, average loss= 0.261805, average accuracy= 94.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 10900, average loss= 0.389474, average accuracy= 84.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 11000, average loss= 0.322304, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 11100, average loss= 0.212576, average accuracy= 94.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 11200, average loss= 0.411512, average accuracy= 84.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 11300, average loss= 0.262906, average accuracy= 92.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 11400, average loss= 0.248246, average accuracy= 94.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 11500, average loss= 0.274613, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 11600, average loss= 0.306465, average accuracy= 88.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 11700, average loss= 0.360337, average accuracy= 82.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 11800, average loss= 0.270187, average accuracy= 88.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 11900, average loss= 0.259626, average accuracy= 92.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 12000, average loss= 0.241178, average accuracy= 92.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 12100, average loss= 0.319876, average accuracy= 86.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 12200, average loss= 0.203026, average accuracy= 94.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 12300, average loss= 0.271175, average accuracy= 86.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 12400, average loss= 0.291146, average accuracy= 88.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 12500, average loss= 0.205515, average accuracy= 90.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 12600, average loss= 0.327230, average accuracy= 86.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 12700, average loss= 0.336650, average accuracy= 84.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 12800, average loss= 0.192163, average accuracy= 90.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 12900, average loss= 0.291405, average accuracy= 88.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 13000, average loss= 0.158699, average accuracy= 93.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Steve]
# Iter = 13100, average loss= 0.213588, average accuracy= 93.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 13200, average loss= 0.234046, average accuracy= 90.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 13300, average loss= 0.230355, average accuracy= 90.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 13400, average loss= 0.213277, average accuracy= 90.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 13500, average loss= 0.375779, average accuracy= 89.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 13600, average loss= 0.282352, average accuracy= 91.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 13700, average loss= 0.285956, average accuracy= 91.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 13800, average loss= 0.126648, average accuracy= 99.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 13900, average loss= 0.090068, average accuracy= 99.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 14000, average loss= 0.191838, average accuracy= 94.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 14100, average loss= 0.141220, average accuracy= 97.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 14200, average loss= 0.247414, average accuracy= 92.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 14300, average loss= 0.216647, average accuracy= 95.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 14400, average loss= 0.247044, average accuracy= 93.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 14500, average loss= 0.133499, average accuracy= 97.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 14600, average loss= 0.182674, average accuracy= 95.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 14700, average loss= 0.159687, average accuracy= 98.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 14800, average loss= 0.233313, average accuracy= 93.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 14900, average loss= 0.228928, average accuracy= 94.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 15000, average loss= 0.105140, average accuracy= 98.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 15100, average loss= 0.119243, average accuracy= 97.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 15200, average loss= 0.076722, average accuracy= 99.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 15300, average loss= 0.172688, average accuracy= 94.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 15400, average loss= 0.229071, average accuracy= 92.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 15500, average loss= 0.123535, average accuracy= 96.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 15600, average loss= 0.186850, average accuracy= 95.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 15700, average loss= 0.141159, average accuracy= 95.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 15800, average loss= 0.237180, average accuracy= 93.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 15900, average loss= 0.172379, average accuracy= 98.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 16000, average loss= 0.218673, average accuracy= 92.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 16100, average loss= 0.222834, average accuracy= 94.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 16200, average loss= 0.212277, average accuracy= 94.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 16300, average loss= 0.165584, average accuracy= 96.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 16400, average loss= 0.262817, average accuracy= 92.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 16500, average loss= 0.221107, average accuracy= 92.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 16600, average loss= 0.195577, average accuracy= 94.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 16700, average loss= 0.219980, average accuracy= 93.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 16800, average loss= 0.217137, average accuracy= 94.00%
# ['with', 'Steve', '.'] - [Steve] vs [Sarah]
# Iter = 16900, average loss= 0.127280, average accuracy= 97.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 17000, average loss= 0.197507, average accuracy= 94.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 17100, average loss= 0.176253, average accuracy= 95.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 17200, average loss= 0.215417, average accuracy= 93.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 17300, average loss= 0.206871, average accuracy= 95.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 17400, average loss= 0.170211, average accuracy= 94.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 17500, average loss= 0.170787, average accuracy= 95.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 17600, average loss= 0.243099, average accuracy= 90.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 17700, average loss= 0.143280, average accuracy= 96.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 17800, average loss= 0.219275, average accuracy= 92.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 17900, average loss= 0.217790, average accuracy= 91.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 18000, average loss= 0.184696, average accuracy= 92.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 18100, average loss= 0.210399, average accuracy= 93.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 18200, average loss= 0.140973, average accuracy= 95.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 18300, average loss= 0.191160, average accuracy= 94.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 18400, average loss= 0.144938, average accuracy= 94.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 18500, average loss= 0.193118, average accuracy= 96.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 18600, average loss= 0.249224, average accuracy= 90.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 18700, average loss= 0.118783, average accuracy= 97.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 18800, average loss= 0.149231, average accuracy= 96.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 18900, average loss= 0.108278, average accuracy= 98.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 19000, average loss= 0.147163, average accuracy= 95.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 19100, average loss= 0.160156, average accuracy= 94.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 19200, average loss= 0.174678, average accuracy= 93.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 19300, average loss= 0.151300, average accuracy= 94.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 19400, average loss= 0.226499, average accuracy= 91.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 19500, average loss= 0.159081, average accuracy= 93.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 19600, average loss= 0.154865, average accuracy= 94.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 19700, average loss= 0.189583, average accuracy= 95.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 19800, average loss= 0.166684, average accuracy= 94.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 19900, average loss= 0.214563, average accuracy= 91.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 20000, average loss= 0.229222, average accuracy= 92.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 20100, average loss= 0.160023, average accuracy= 94.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 20200, average loss= 0.173865, average accuracy= 93.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 20300, average loss= 0.137608, average accuracy= 95.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 20400, average loss= 0.158630, average accuracy= 94.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 20500, average loss= 0.171317, average accuracy= 92.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 20600, average loss= 0.103289, average accuracy= 97.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 20700, average loss= 0.112541, average accuracy= 94.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 20800, average loss= 0.216855, average accuracy= 91.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 20900, average loss= 0.092440, average accuracy= 97.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 21000, average loss= 0.152451, average accuracy= 94.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 21100, average loss= 0.125545, average accuracy= 95.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 21200, average loss= 0.153860, average accuracy= 92.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 21300, average loss= 0.112897, average accuracy= 95.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 21400, average loss= 0.146340, average accuracy= 95.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 21500, average loss= 0.104631, average accuracy= 96.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 21600, average loss= 0.105015, average accuracy= 96.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 21700, average loss= 0.164631, average accuracy= 93.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 21800, average loss= 0.063239, average accuracy= 99.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 21900, average loss= 0.114974, average accuracy= 97.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 22000, average loss= 0.130813, average accuracy= 95.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 22100, average loss= 0.069022, average accuracy= 98.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 22200, average loss= 0.084424, average accuracy= 98.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 22300, average loss= 0.135431, average accuracy= 95.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 22400, average loss= 0.102851, average accuracy= 96.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 22500, average loss= 0.086977, average accuracy= 97.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 22600, average loss= 0.082201, average accuracy= 98.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 22700, average loss= 0.139380, average accuracy= 95.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 22800, average loss= 0.146110, average accuracy= 94.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 22900, average loss= 0.070168, average accuracy= 97.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 23000, average loss= 0.101684, average accuracy= 95.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 23100, average loss= 0.156170, average accuracy= 91.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 23200, average loss= 0.097779, average accuracy= 98.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 23300, average loss= 0.087543, average accuracy= 96.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 23400, average loss= 0.106008, average accuracy= 95.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 23500, average loss= 0.119479, average accuracy= 94.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 23600, average loss= 0.111454, average accuracy= 94.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 23700, average loss= 0.128273, average accuracy= 99.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 23800, average loss= 0.123826, average accuracy= 97.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 23900, average loss= 0.085897, average accuracy= 96.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 24000, average loss= 0.073454, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 24100, average loss= 0.084158, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 24200, average loss= 0.088799, average accuracy= 96.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 24300, average loss= 0.101856, average accuracy= 97.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 24400, average loss= 0.075045, average accuracy= 97.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 24500, average loss= 0.051827, average accuracy= 98.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 24600, average loss= 0.099540, average accuracy= 96.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 24700, average loss= 0.092638, average accuracy= 98.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 24800, average loss= 0.060030, average accuracy= 98.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 24900, average loss= 0.084197, average accuracy= 99.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 25000, average loss= 0.049330, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 25100, average loss= 0.081538, average accuracy= 99.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 25200, average loss= 0.086453, average accuracy= 97.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 25300, average loss= 0.081273, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 25400, average loss= 0.079906, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 25500, average loss= 0.089911, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 25600, average loss= 0.045873, average accuracy= 99.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 25700, average loss= 0.098119, average accuracy= 99.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 25800, average loss= 0.072241, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 25900, average loss= 0.058713, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 26000, average loss= 0.072146, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 26100, average loss= 0.041809, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 26200, average loss= 0.068432, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 26300, average loss= 0.056325, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 26400, average loss= 0.067498, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 26500, average loss= 0.075400, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 26600, average loss= 0.043395, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 26700, average loss= 0.080935, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 26800, average loss= 0.071318, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 26900, average loss= 0.045596, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 27000, average loss= 0.055123, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 27100, average loss= 0.051101, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 27200, average loss= 0.045899, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 27300, average loss= 0.041404, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 27400, average loss= 0.044789, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 27500, average loss= 0.059879, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 27600, average loss= 0.033912, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 27700, average loss= 0.039194, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 27800, average loss= 0.049355, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 27900, average loss= 0.058890, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 28000, average loss= 0.040044, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 28100, average loss= 0.023467, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 28200, average loss= 0.035821, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 28300, average loss= 0.045983, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 28400, average loss= 0.032982, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 28500, average loss= 0.045332, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 28600, average loss= 0.049024, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 28700, average loss= 0.034553, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 28800, average loss= 0.042544, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 28900, average loss= 0.030517, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 29000, average loss= 0.025243, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 29100, average loss= 0.028392, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 29200, average loss= 0.026665, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 29300, average loss= 0.019609, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 29400, average loss= 0.024615, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 29500, average loss= 0.024259, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 29600, average loss= 0.038452, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 29700, average loss= 0.020251, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 29800, average loss= 0.027646, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 29900, average loss= 0.016399, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 30000, average loss= 0.023899, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 30100, average loss= 0.021657, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 30200, average loss= 0.025298, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 30300, average loss= 0.029675, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 30400, average loss= 0.023528, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 30500, average loss= 0.031782, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 30600, average loss= 0.023160, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 30700, average loss= 0.020548, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 30800, average loss= 0.019868, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 30900, average loss= 0.016677, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 31000, average loss= 0.018258, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 31100, average loss= 0.021741, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 31200, average loss= 0.016274, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 31300, average loss= 0.020716, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 31400, average loss= 0.017756, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 31500, average loss= 0.014375, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 31600, average loss= 0.012303, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 31700, average loss= 0.009865, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 31800, average loss= 0.018356, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 31900, average loss= 0.016373, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 32000, average loss= 0.015782, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 32100, average loss= 0.022350, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 32200, average loss= 0.016875, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 32300, average loss= 0.018773, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 32400, average loss= 0.012691, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 32500, average loss= 0.008968, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 32600, average loss= 0.014111, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 32700, average loss= 0.009718, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 32800, average loss= 0.007732, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 32900, average loss= 0.015318, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 33000, average loss= 0.010165, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 33100, average loss= 0.012146, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 33200, average loss= 0.009970, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 33300, average loss= 0.007587, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 33400, average loss= 0.010705, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 33500, average loss= 0.009693, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 33600, average loss= 0.007286, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 33700, average loss= 0.008949, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 33800, average loss= 0.007306, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 33900, average loss= 0.005774, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 34000, average loss= 0.005008, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 34100, average loss= 0.006100, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 34200, average loss= 0.007569, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 34300, average loss= 0.005185, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 34400, average loss= 0.005913, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 34500, average loss= 0.004283, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 34600, average loss= 0.006057, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 34700, average loss= 0.005890, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 34800, average loss= 0.004301, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 34900, average loss= 0.007266, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 35000, average loss= 0.007419, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 35100, average loss= 0.005026, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 35200, average loss= 0.005475, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 35300, average loss= 0.007115, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 35400, average loss= 0.004878, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 35500, average loss= 0.005174, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 35600, average loss= 0.002433, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 35700, average loss= 0.005183, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 35800, average loss= 0.002400, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 35900, average loss= 0.004520, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 36000, average loss= 0.003479, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 36100, average loss= 0.003329, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 36200, average loss= 0.002717, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 36300, average loss= 0.003159, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 36400, average loss= 0.003528, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 36500, average loss= 0.001771, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 36600, average loss= 0.002507, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 36700, average loss= 0.003200, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 36800, average loss= 0.002595, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 36900, average loss= 0.003170, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 37000, average loss= 0.002470, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 37100, average loss= 0.002812, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 37200, average loss= 0.001401, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 37300, average loss= 0.001742, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 37400, average loss= 0.001297, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 37500, average loss= 0.001582, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 37600, average loss= 0.001306, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 37700, average loss= 0.002209, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 37800, average loss= 0.001564, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 37900, average loss= 0.001698, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 38000, average loss= 0.001465, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 38100, average loss= 0.001602, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 38200, average loss= 0.001361, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 38300, average loss= 0.001673, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 38400, average loss= 0.001688, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 38500, average loss= 0.001224, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 38600, average loss= 0.001117, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 38700, average loss= 0.001166, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 38800, average loss= 0.001154, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 38900, average loss= 0.001171, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 39000, average loss= 0.001208, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 39100, average loss= 0.000969, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 39200, average loss= 0.000811, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 39300, average loss= 0.000920, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 39400, average loss= 0.000549, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 39500, average loss= 0.000827, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 39600, average loss= 0.000914, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 39700, average loss= 0.000670, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 39800, average loss= 0.000728, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 39900, average loss= 0.000662, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 40000, average loss= 0.000698, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 40100, average loss= 0.000934, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 40200, average loss= 0.000739, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 40300, average loss= 0.000519, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 40400, average loss= 0.000548, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 40500, average loss= 0.000493, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 40600, average loss= 0.000577, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 40700, average loss= 0.000704, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 40800, average loss= 0.000418, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 40900, average loss= 0.000442, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 41000, average loss= 0.000555, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 41100, average loss= 0.000523, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 41200, average loss= 0.000483, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 41300, average loss= 0.000483, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 41400, average loss= 0.000499, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 41500, average loss= 0.000323, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 41600, average loss= 0.000280, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 41700, average loss= 0.000335, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 41800, average loss= 0.000240, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 41900, average loss= 0.000407, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 42000, average loss= 0.000304, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 42100, average loss= 0.000268, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 42200, average loss= 0.000243, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 42300, average loss= 0.000351, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 42400, average loss= 0.000311, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 42500, average loss= 0.000341, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 42600, average loss= 0.000280, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 42700, average loss= 0.000202, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 42800, average loss= 0.000215, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 42900, average loss= 0.000254, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 43000, average loss= 0.000234, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 43100, average loss= 0.000234, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 43200, average loss= 0.000172, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 43300, average loss= 0.000245, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 43400, average loss= 0.000222, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 43500, average loss= 0.000176, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 43600, average loss= 0.000181, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 43700, average loss= 0.000147, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 43800, average loss= 0.000134, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 43900, average loss= 0.000165, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 44000, average loss= 0.000148, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 44100, average loss= 0.000114, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 44200, average loss= 0.000131, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 44300, average loss= 0.000099, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 44400, average loss= 0.000110, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 44500, average loss= 0.000169, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 44600, average loss= 0.000131, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 44700, average loss= 0.000117, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 44800, average loss= 0.000108, average accuracy= 100.00%
# ['Sarah', 'had', 'dinner'] - [with] vs [with]
# Iter = 44900, average loss= 0.000108, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 45000, average loss= 0.000096, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 45100, average loss= 0.000106, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 45200, average loss= 0.000078, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 45300, average loss= 0.000114, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 45400, average loss= 0.000070, average accuracy= 100.00%
# ['Steve', 'had', 'breakfast'] - [with] vs [with]
# Iter = 45500, average loss= 0.000095, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 45600, average loss= 0.000073, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 45700, average loss= 0.000069, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 45800, average loss= 0.000063, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 45900, average loss= 0.000068, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 46000, average loss= 0.000069, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 46100, average loss= 0.000068, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 46200, average loss= 0.000062, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 46300, average loss= 0.000059, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 46400, average loss= 0.000075, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 46500, average loss= 0.000055, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 46600, average loss= 0.000066, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 46700, average loss= 0.000062, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 46800, average loss= 0.000048, average accuracy= 100.00%
# ['had', 'breakfast', 'with'] - [David] vs [David]
# Iter = 46900, average loss= 0.000041, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 47000, average loss= 0.000047, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 47100, average loss= 0.000042, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 47200, average loss= 0.000045, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 47300, average loss= 0.000042, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 47400, average loss= 0.000051, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 47500, average loss= 0.000048, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 47600, average loss= 0.000025, average accuracy= 100.00%
# ['with', 'Steve', '.'] - [Steve] vs [Steve]
# Iter = 47700, average loss= 0.000045, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 47800, average loss= 0.000037, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 47900, average loss= 0.000037, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 48000, average loss= 0.000038, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 48100, average loss= 0.000022, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 48200, average loss= 0.000029, average accuracy= 100.00%
# ['breakfast', 'with', 'David'] - [.] vs [.]
# Iter = 48300, average loss= 0.000043, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 48400, average loss= 0.000030, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 48500, average loss= 0.000040, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 48600, average loss= 0.000020, average accuracy= 100.00%
# ['lunch', 'with', 'Sarah'] - [.] vs [.]
# Iter = 48700, average loss= 0.000025, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 48800, average loss= 0.000024, average accuracy= 100.00%
# ['dinner', 'with', 'Steve'] - [.] vs [.]
# Iter = 48900, average loss= 0.000026, average accuracy= 100.00%
# ['had', 'dinner', 'with'] - [Steve] vs [Steve]
# Iter = 49000, average loss= 0.000027, average accuracy= 100.00%
# ['Steve', '.', 'Steve'] - [had] vs [had]
# Iter = 49100, average loss= 0.000016, average accuracy= 100.00%
# ['with', 'Sarah', '.'] - [Sarah] vs [Sarah]
# Iter = 49200, average loss= 0.000019, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 49300, average loss= 0.000017, average accuracy= 100.00%
# ['Sarah', '.', 'Sarah'] - [had] vs [had]
# Iter = 49400, average loss= 0.000023, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 49500, average loss= 0.000021, average accuracy= 100.00%
# ['David', 'had', 'lunch'] - [with] vs [with]
# Iter = 49600, average loss= 0.000021, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 49700, average loss= 0.000019, average accuracy= 100.00%
# ['had', 'lunch', 'with'] - [Sarah] vs [Sarah]
# Iter = 49800, average loss= 0.000023, average accuracy= 100.00%
# ['.', 'Sarah', 'had'] - [dinner] vs [dinner]
# Iter = 49900, average loss= 0.000018, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Iter = 50000, average loss= 0.000014, average accuracy= 100.00%
# ['.', 'Steve', 'had'] - [breakfast] vs [breakfast]
# Optimization Finished!
# Elapsed time:  49.19858908653259 second(s)
# insert 3 words: Davis Sarah Steve
# cannot be found in dictionary
# insert 3 words: David Sarah Steve
# David Sarah Steve had breakfast with David . Sarah had dinner with Steve
# insert 3 words: David had breakfast
# David had breakfast with David . Sarah had dinner with Steve . Steve
